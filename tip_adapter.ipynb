# %% [markdown]
# <a href="https://colab.research.google.com/github/oz-e/applied-ml/blob/main/tip_adapter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/gaopengcuhk/Tip-Adapter.git
# %cd Tip-Adapter

# !pip install -r requirements.txt
# Out:
# Cloning into 'Tip-Adapter'...
# remote: Enumerating objects: 156, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 156 (delta 48), reused 30 (delta 30), pack-reused 93 (from 1)
# Receiving objects: 100% (156/156), 7.60 MiB | 12.79 MiB/s, done.
# Resolving deltas: 100% (64/64), done.
# /content/Tip-Adapter
# /bin/bash: line 1: conda: command not found
# /bin/bash: line 1: conda: command not found
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.9/69.9 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.3/185.3 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 74.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.4 MB/s eta 0:00:00
# ...

# %%
import torchvision

torchvision.datasets.Caltech101('', download=True)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=137RyRjvTBkBiIfeYBNZBtViDHQ6_Ewsp
# From (redirected): https://drive.usercontent.google.com/download?id=137RyRjvTBkBiIfeYBNZBtViDHQ6_Ewsp&confirm=t&uuid=fefd9ff8-4fe8-49d6-86ab-1d87f8268a64
# To: /content/Tip-Adapter/caltech101/101_ObjectCategories.tar.gz
# 100%|██████████| 132M/132M [00:02<00:00, 54.7MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=175kQy3UsZ0wUEHZjqkUDdNVssr7bgh_m
# From (redirected): https://drive.usercontent.google.com/download?id=175kQy3UsZ0wUEHZjqkUDdNVssr7bgh_m&confirm=t&uuid=02e01dd9-29d7-45a4-a324-219d915ccf51
# To: /content/Tip-Adapter/caltech101/Annotations.tar
# 100%|██████████| 14.0M/14.0M [00:00<00:00, 50.9MB/s]
# Dataset Caltech101
#     Number of datapoints: 8677
#     Root location: caltech101
#     Target type: ['category']

# %%
import gdown

gdown.download(id='1hyarUivQE36mY6jSomru6Fjd-JzwcCzN', output='caltech101/split_zhou_Caltech101.json')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1hyarUivQE36mY6jSomru6Fjd-JzwcCzN
# To: /content/Tip-Adapter/caltech101/split_zhou_Caltech101.json
# 100%|██████████| 809k/809k [00:00<00:00, 8.19MB/s]
# 'caltech101/split_zhou_Caltech101.json'

# %%
import os

if os.path.exists('caltech101'):
  # !mv caltech101 caltech-101

# %%
# !python main.py --config configs/caltech101.yaml
# Out:
# Running configs.
# {'root_path': '', 'load_cache': False, 'load_pre_feat': False, 'search_hp': True, 'search_scale': [12, 5], 'search_step': [200, 20], 'init_beta': 1, 'init_alpha': 3, 'dataset': 'caltech101', 'shots': 16, 'backbone': 'RN50', 'lr': 0.001, 'augment_epoch': 10, 'train_epoch': 20, 'cache_dir': './caches/caltech101'}
#
# 100%|███████████████████████████████████████| 244M/244M [00:09<00:00, 27.1MiB/s]
# Preparing dataset.
# Reading split from caltech-101/split_zhou_Caltech101.json
# Creating a 16-shot dataset
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
#
# ...
