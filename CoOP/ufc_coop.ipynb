# %%
# !pip install git+https://github.com/KaiyangZhou/Dassl.pytorch.git
# Out:
# ...
#   Cloning https://github.com/KaiyangZhou/Dassl.pytorch.git to /tmp/pip-req-build-lzky6710
#   Running command git clone --filter=blob:none --quiet https://github.com/KaiyangZhou/Dassl.pytorch.git /tmp/pip-req-build-lzky6710
#   Resolved https://github.com/KaiyangZhou/Dassl.pytorch.git to commit c61a1b570ac6333bd50fb5ae06aea59002fb20bb
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.9/69.9 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.3/185.3 kB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 81.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 6.6 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/KaiyangZhou/CoOp.git
# Out:
# Cloning into 'CoOp'...
# remote: Enumerating objects: 455, done.
# remote: Counting objects: 100% (250/250), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 455 (delta 217), reused 198 (delta 198), pack-reused 205 (from 1)
# Receiving objects: 100% (455/455), 1.40 MiB | 9.19 MiB/s, done.
# Resolving deltas: 100% (266/266), done.

# %%
# !chmod -R +x CoOp/

# %%
# !mkdir datasets/

# %%
# %cd datasets/
# Out:
# /content/datasets

# %%
# !mkdir ucf101/
# %cd ucf101
# Out:
# /content/datasets/ufc101

# %%
# !gdown 10Jqome3vtUA2keJkNanAiFpgbyC9Hc2O
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=10Jqome3vtUA2keJkNanAiFpgbyC9Hc2O
# From (redirected): https://drive.google.com/uc?id=10Jqome3vtUA2keJkNanAiFpgbyC9Hc2O&confirm=t&uuid=f35e6a20-980c-4344-9dd3-74454e79821a
# To: /content/datasets/ufc101/UCF-101-midframes.zip
# 100% 140M/140M [00:01<00:00, 135MB/s]
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=I0S0q91hJfsV9Gf4xDIjgDq4AqBNJb1y
#
# but Gdown can't. Please check connections and permissions.

# %%
# !gdown 1iKdzYX0joXCSsNYwvh-AM9K6PCJF-k_0
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1iKdzYX0joXCSsNYwvh-AM9K6PCJF-k_0
# To: /content/datasets/ufc101/split_zhou_UCF101.json
# 100% 1.56M/1.56M [00:00<00:00, 194MB/s]

# %%
# !unzip UCF-101-midframes.zip
# !rm UCF-101-midframes.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: UCF-101-midframes/Sky_Diving/v_SkyDiving_g09_c01.jpg
#   inflating: UCF-101-midframes/Sky_Diving/v_SkyDiving_g05_c02.jpg
#   inflating: UCF-101-midframes/Sky_Diving/v_SkyDiving_g03_c05.jpg
#   inflating: UCF-101-midframes/Sky_Diving/v_SkyDiving_g19_c03.jpg
#   inflating: UCF-101-midframes/Sky_Diving/v_SkyDiving_g04_c04.jpg
#   inflating: UCF-101-midframes/Sky_Diving/v_SkyDiving_g16_c02.jpg
#   inflating: UCF-101-midframes/Sky_Diving/v_SkyDiving_g02_c02.jpg
#   inflating: UCF-101-midframes/Sky_Diving/v_SkyDiving_g16_c03.jpg
#   inflating: UCF-101-midframes/Sky_Diving/v_SkyDiving_g18_c01.jpg
#   inflating: UCF-101-midframes/Sky_Diving/v_SkyDiving_g11_c02.jpg
#   inflating: UCF-101-midframes/Sky_Diving/v_SkyDiving_g07_c05.jpg
#   inflating: UCF-101-midframes/Sky_Diving/v_SkyDiving_g03_c02.jpg
#   inflating: UCF-101-midframes/Sky_Diving/v_SkyDiving_g20_c04.jpg
# ...

# %%
# %cd ../
# Out:
# /content/datasets

# %%
# %cd ../
# Out:
# /content

# %%
# %cd CoOp/
# Out:
# /content/CoOp

# %%
# !pip install -r requirements.txt

# %%
# !sed -i 's/DATA=\/path\/to\/datasets/DATA=\/content\/datasets/g' scripts/coop/main.sh

# %%
# !scripts/coop/main.sh ucf101 vit_b16 end 16 16 False
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch [172/200] batch [15/50] time 0.048 (0.076) data 0.000 (0.028) loss 0.4224 (0.5390) acc 90.6250 (85.8333) lr 1.0899e-04 eta 0:01:49
# epoch [172/200] batch [20/50] time 0.046 (0.069) data 0.000 (0.021) loss 0.5620 (0.5442) acc 81.2500 (85.6250) lr 1.0899e-04 eta 0:01:38
# epoch [172/200] batch [25/50] time 0.046 (0.065) data 0.001 (0.017) loss 0.4607 (0.5446) acc 81.2500 (85.2500) lr 1.0899e-04 eta 0:01:32
# epoch [172/200] batch [30/50] time 0.053 (0.062) data 0.000 (0.014) loss 0.8394 (0.5882) acc 84.3750 (84.1667) lr 1.0899e-04 eta 0:01:28
# epoch [172/200] batch [35/50] time 0.045 (0.060) data 0.001 (0.012) loss 0.5166 (0.5737) acc 81.2500 (84.3750) lr 1.0899e-04 eta 0:01:25
# epoch [172/200] batch [40/50] time 0.045 (0.058) data 0.000 (0.011) loss 0.7930 (0.5667) acc 84.3750 (84.8438) lr 1.0899e-04 eta 0:01:22
# ...

# %%
# !python parse_test_res.py /content/CoOp/output/ucf101/CoOp/vit_b16_16shots/nctx16_cscFalse_ctpend
# Out:
# Parsing files in /content/CoOp/output/ucf101/CoOp/vit_b16_16shots/nctx16_cscFalse_ctpend
# file: /content/CoOp/output/ucf101/CoOp/vit_b16_16shots/nctx16_cscFalse_ctpend/seed1/log.txt. accuracy: 82.00%.
# file: /content/CoOp/output/ucf101/CoOp/vit_b16_16shots/nctx16_cscFalse_ctpend/seed2/log.txt. accuracy: 83.10%.
# file: /content/CoOp/output/ucf101/CoOp/vit_b16_16shots/nctx16_cscFalse_ctpend/seed3/log.txt. accuracy: 81.90%.
# ===
# Summary of directory: /content/CoOp/output/ucf101/CoOp/vit_b16_16shots/nctx16_cscFalse_ctpend
# * accuracy: 82.33% +- 0.54%
# ===

# %%
# Read the file
file_path = "/content/CoOp/interpret_prompt.py"
with open(file_path, "r") as file:
    lines = file.readlines()

with open(file_path, "r") as file:
    lines = file.readlines()

# Modify line 44 (index 43)
lines[43] = 'prompt_learner = torch.load(fpath, map_location="cpu", weights_only=False)["state_dict"]\n'

# Write the modified lines back
with open(file_path, "w") as file:
    file.writelines(lines)

# %%
# !python interpret_prompt.py /content/CoOp/output/ucf101/CoOp/vit_b16_16shots/nctx16_cscFalse_ctpend/seed3/prompt_learner/model.pth.tar-200 3
# Out:
# Return the top-3 matched words
# 100%|███████████████████████████████████████| 256M/256M [00:08<00:00, 31.5MiB/s]
# Size of token embedding: torch.Size([49408, 512])
# Size of context: torch.Size([16, 512])
# Size of distance matrix: torch.Size([16, 49408])
# 1: ['point</w>', 'mitchell</w>', 'oe</w>'] ['0.6671', '0.6676', '0.6685']
# 2: ['teria</w>', 'dinners</w>', 'ents</w>'] ['1.6117', '1.6118', '1.6128']
# 3: ['isil</w>', 'disclaimer</w>', 'stephanie</w>'] ['1.2752', '1.2753', '1.2761']
# 4: ['ido</w>', 'booth</w>', 'ðŁĺĭ'] ['1.8319', '1.8332', '1.8347']
# 5: ['australia</w>', 'dolphin</w>', 'santorini</w>'] ['1.6144', '1.6198', '1.6209']
# 6: ['elephants</w>', 'ukrainian</w>', 'atx</w>'] ['1.3092', '1.3184', '1.3237']
# 7: ['ballots</w>', 'crowd</w>', 'ruption</w>'] ['1.3525', '1.3559', '1.3575']
# 8: ['palli', 'bridge', 'anus</w>'] ['1.8623', '1.8689', '1.8690']
# 9: ['meant</w>', 'aml</w>', 'ka'] ['0.8425', '0.8443', '0.8465']
# ...
