# %%
# !git clone https://github.com/SlightlyCodic/AML.git
# Out:
# Cloning into 'AML'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !pip install git+https://github.com/KaiyangZhou/Dassl.pytorch.git
# Out:
# ...
#   Cloning https://github.com/KaiyangZhou/Dassl.pytorch.git to /tmp/pip-req-build-ce4rmz7c
#   Running command git clone --filter=blob:none --quiet https://github.com/KaiyangZhou/Dassl.pytorch.git /tmp/pip-req-build-ce4rmz7c
#   Resolved https://github.com/KaiyangZhou/Dassl.pytorch.git to commit c61a1b570ac6333bd50fb5ae06aea59002fb20bb
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.9/69.9 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.3/185.3 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 82.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 6.7 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/KaiyangZhou/CoOp.git
# Out:
# Cloning into 'CoOp'...
# remote: Enumerating objects: 455, done.
# remote: Counting objects: 100% (250/250), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 455 (delta 217), reused 199 (delta 199), pack-reused 205 (from 1)
# Receiving objects: 100% (455/455), 1.40 MiB | 19.92 MiB/s, done.
# Resolving deltas: 100% (266/266), done.

# %%
# !chmod -R +x CoOp/

# %%
# !mkdir datasets

# %%
datasets_path = "/content/datasets"

# %%
import sys
sys.path.append('/content/AML')

# %%
import AML.CoOP_dataset as datasets
oxford_pets_dataset = datasets.OxfordIIITPet(datasets_path, split='train')
# Out:
# 100%|██████████| 792M/792M [00:22<00:00, 34.5MB/s]
# 100%|██████████| 19.2M/19.2M [00:01<00:00, 16.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1501r8Ber4nNKvmlFVQZ8SeUHTcdTTEqs
# To: /content/datasets/oxford-iiit-pet/split.json
# 100%|██████████| 724k/724k [00:00<00:00, 138MB/s]

# %%
oxford_pets_dataset
# Out:
# Dataset OxfordIIITPet
#     Number of datapoints: 2944
#     Root location: /content/datasets/oxford-iiit-pet

# %%
# %cd CoOp/
# Out:
# /content/CoOp

# %%
# !pip install -r requirements.txt

# %%
# !sed -i 's/DATA=\/path\/to\/datasets/DATA=\/content\/datasets/g' scripts/coop/main.sh

# %%
# !scripts/coop/main.sh oxford_pets vit_b16 end 16 16 False
# Out:
# 2025-05-09 16:35:29.585900: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-09 16:35:29.603246: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746808529.624279    5419 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746808529.630740    5419 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python parse_test_res.py /content/CoOp/output/oxford_pets/CoOp/vit_b16_16shots/nctx16_cscFalse_ctpend
# Out:
# Parsing files in /content/CoOp/output/oxford_pets/CoOp/vit_b16_16shots/nctx16_cscFalse_ctpend
# file: /content/CoOp/output/oxford_pets/CoOp/vit_b16_16shots/nctx16_cscFalse_ctpend/seed1/log.txt. accuracy: 92.80%.
# file: /content/CoOp/output/oxford_pets/CoOp/vit_b16_16shots/nctx16_cscFalse_ctpend/seed2/log.txt. accuracy: 91.80%.
# file: /content/CoOp/output/oxford_pets/CoOp/vit_b16_16shots/nctx16_cscFalse_ctpend/seed3/log.txt. accuracy: 92.20%.
# ===
# Summary of directory: /content/CoOp/output/oxford_pets/CoOp/vit_b16_16shots/nctx16_cscFalse_ctpend
# * accuracy: 92.27% +- 0.41%
# ===

# %%
# Read the file
file_path = "/content/CoOp/interpret_prompt.py"
with open(file_path, "r") as file:
    lines = file.readlines()

with open(file_path, "r") as file:
    lines = file.readlines()

# Modify line 44 (index 43)
lines[43] = 'prompt_learner = torch.load(fpath, map_location="cpu", weights_only=False)["state_dict"]\n'

# Write the modified lines back
with open(file_path, "w") as file:
    file.writelines(lines)

# %%
# !python interpret_prompt.py /content/CoOp/output/oxford_pets/CoOp/vit_b16_16shots/nctx16_cscFalse_ctpend/seed3/prompt_learner/model.pth.tar-200 3
# Out:
# Return the top-3 matched words
# Size of token embedding: torch.Size([49408, 512])
# Size of context: torch.Size([16, 512])
# Size of distance matrix: torch.Size([16, 49408])
# 1: ['latest', 'sir', 'helpers</w>'] ['1.3487', '1.3522', '1.3554']
# 2: ['bates</w>', 'lisboa</w>', 'solomon</w>'] ['0.9778', '0.9813', '0.9823']
# 3: ['ahem</w>', 'le', 'puppylove</w>'] ['1.4618', '1.4619', '1.4624']
# 4: ['oops</w>', 'megam', 'manafort</w>'] ['1.1859', '1.1892', '1.1918']
# 5: ['skull</w>', 'gifted</w>', 'isc</w>'] ['1.4417', '1.4468', '1.4473']
# 6: ['chow</w>', 'prover', 'ĸ'] ['0.8182', '0.8287', '0.8297']
# 7: ['staples</w>', 'pez</w>', 'tsu</w>'] ['1.3951', '1.3968', '1.3983']
# 8: ['toi', 'ingl', 'chang'] ['1.6634', '1.6650', '1.6652']
# 9: ['ghar</w>', 'cafes</w>', 'asse'] ['1.2428', '1.2432', '1.2433']
# 10: ['ðŁĴĶ', 'enquiry</w>', 'bleeds</w>'] ['1.2691', '1.2742', '1.2746']
# 11: ['coastline</w>', 'bars</w>', 'lap</w>'] ['0.8560', '0.8645', '0.8655']
# ...
